# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Building_Violations_sample_50000.csv');

# %%
df.shape
# Out:
# (50000, 23)

# %%
df.head()
# Out:
#    Unnamed: 0       ID VIOLATION LAST MODIFIED DATE VIOLATION DATE  \
# 0           0  5063843                      5/21/15        5/21/15
# 1           1  5063990                      5/21/15        5/21/15
# 2           2  5064022                      5/21/15        5/21/15
# 3           3  5064019                      5/21/15        5/21/15
# 4           4  5064139                      5/21/15        5/21/15
#
#   VIOLATION CODE VIOLATION STATUS VIOLATION STATUS DATE  \
# 0       CN065014             OPEN                   NaN
# 1       CN044013             OPEN                   NaN
# 2       CN104035             OPEN                   NaN
# 3       CN196029             OPEN                   NaN
# 4       CN104015             OPEN                   NaN
#
#             VIOLATION DESCRIPTION             VIOLATION LOCATION  \
# 0                  REPAIR LINTELS                 OTHER   :    :
# 1  PIPE OPENING W/NONCOMBUST MATL  OTHER   :    :MULTIPLE FLOORS
# ...

# %%
del df['Unnamed: 0']

# %%
df.shape
# Out:
# (50000, 22)

# %%
df.columns
# Out:
# Index([u'ID', u'VIOLATION LAST MODIFIED DATE', u'VIOLATION DATE', u'VIOLATION CODE', u'VIOLATION STATUS', u'VIOLATION STATUS DATE', u'VIOLATION DESCRIPTION', u'VIOLATION LOCATION', u'VIOLATION INSPECTOR COMMENTS', u'VIOLATION ORDINANCE', u'INSPECTOR ID', u'INSPECTION NUMBER', u'INSPECTION STATUS', u'INSPECTION WAIVED', u'INSPECTION CATEGORY', u'DEPARTMENT BUREAU', u'ADDRESS', u'PROPERTY GROUP', u'SSA', u'LATITUDE', u'LONGITUDE', u'LOCATION'], dtype='object')

# %%
import re

def spaces_to_snakes(column_names):
    
    s = re.sub(r"\s+", '_', column_names)
    return s.lower()

df.columns = [spaces_to_snakes(col) for col in df.columns]

# %%
df.columns
# Out:
# Index([u'id', u'violation_last_modified_date', u'violation_date', u'violation_code', u'violation_status', u'violation_status_date', u'violation_description', u'violation_location', u'violation_inspector_comments', u'violation_ordinance', u'inspector_id', u'inspection_number', u'inspection_status', u'inspection_waived', u'inspection_category', u'department_bureau', u'address', u'property_group', u'ssa', u'latitude', u'longitude', u'location'], dtype='object')

# %%
df.violation_date = pd.to_datetime(df.violation_date)
df.violation_date.head()
# Out:
# 0   2015-05-21
# 1   2015-05-21
# 2   2015-05-21
# 3   2015-05-21
# 4   2015-05-21
# Name: violation_date, dtype: datetime64[ns]

# %%
df['new_lat'] = df.latitude.apply(lambda x: x + np.random.rand())

# %%
df.head(5)
# Out:
#         id violation_last_modified_date violation_date violation_code  \
# 0  5063843                      5/21/15     2015-05-21       CN065014
# 1  5063990                      5/21/15     2015-05-21       CN044013
# 2  5064022                      5/21/15     2015-05-21       CN104035
# 3  5064019                      5/21/15     2015-05-21       CN196029
# 4  5064139                      5/21/15     2015-05-21       CN104015
#
#   violation_status violation_status_date           violation_description  \
# 0             OPEN                   NaN                  REPAIR LINTELS
# 1             OPEN                   NaN  PIPE OPENING W/NONCOMBUST MATL
# 2             OPEN                   NaN                 MAINTAIN WINDOW
# 3             OPEN                   NaN      POST OWNER/MANAGERS NAME/#
# 4             OPEN                   NaN   REPLCE WINDOW PANES, PLEXGLAS
#
#               violation_location  \
# 0                 OTHER   :    :
# 1  OTHER   :    :MULTIPLE FLOORS
# ...

# %%
df_1 = df.isnull();
np.sum(df_1)
# Out:
# id                                  0
# violation_last_modified_date        0
# violation_date                      0
# violation_code                      0
# violation_status                    0
# violation_status_date           36488
# violation_description             376
# violation_location              32484
# violation_inspector_comments     5295
# violation_ordinance              1538
# inspector_id                        0
# inspection_number                   0
# inspection_status                   0
# inspection_waived                   0
# inspection_category                 0
# department_bureau                   0
# address                             0
# property_group                      0
# ssa                             40639
# latitude                           48
# longitude                          48
# location                           48
# new_lat                            48
# dtype: int32

# %%
df['violation_location'].head()
# Out:
# 0                   OTHER   :    :
# 1    OTHER   :    :MULTIPLE FLOORS
# 2                   OTHER   :    :
# 3                   OTHER   :    :
# 4                   OTHER   :    :
# Name: violation_location, dtype: object

# %%
df['property_group'].head()
# Out:
# 0    461523
# 1     19575
# 2    117375
# 3    117375
# 4    344254
# Name: property_group, dtype: int64

# %%
import numpy as np
import scipy as sp
#df.columns()
df['latitude'].fillna('None')
# Out:
# 0     41.73309
# 1     41.77709
# 2     41.93799
# 3     41.93799
# 4     41.79147
# 5     41.81219
# 6     41.79147
# 7     41.76549
# 8     41.96329
# 9     41.98884
# 10    41.95615
# 11    41.95615
# 12    41.79996
# 13    41.83845
# 14    41.79476
# ...
# 49985    41.99831
# 49986    41.96796
# 49987    41.94369
# 49988    41.90869
# 49989    41.85696
# 49990    41.78226
# 49991    41.80288
# 49992    41.77867
# 49993    41.80288
# 49994     41.9977
# 49995    41.75168
# 49996     41.8813
# 49997    41.77607
# 49998    41.80638
# 49999    41.88331
# Name: latitude, Length: 50000, dtype: object

# %%
df.head(2)
# Out:
#         id violation_last_modified_date violation_date violation_code  \
# 0  5063843                      5/21/15     2015-05-21       CN065014
# 1  5063990                      5/21/15     2015-05-21       CN044013
#
#   violation_status violation_status_date           violation_description  \
# 0             OPEN                   NaN                  REPAIR LINTELS
# 1             OPEN                   NaN  PIPE OPENING W/NONCOMBUST MATL
#
#               violation_location  \
# 0                 OTHER   :    :
# 1  OTHER   :    :MULTIPLE FLOORS
#
#                         violation_inspector_comments  \
# 0                                   LINTELS; RUSTED.
# 1  OPENINGS AROUND PIPES, SEAL WITH APPROVED MATE...
#
#                                  violation_ordinance inspector_id  \
# 0  Failed to maintain lintel in good repair and f...      BL00444
# 1  Failed to fill openings around exposed pipes o...      BL00748
#
# ...

# %%
df['longitude'].fillna('None');

# %%
df.head(5)
# Out:
# 0   -87.606184
# 1   -87.615694
# 2   -87.708657
# 3   -87.708657
# 4   -87.620616
# Name: longitude, dtype: float64

# %%
df['violation_status'].describe()
# Out:
# count     50000
# unique        3
# top        OPEN
# freq      36355
# Name: violation_status, dtype: object

# %%
# Filling Missing Value
df['violation_description'].fillna("None")
# Out:
# 0                     REPAIR LINTELS
# 1     PIPE OPENING W/NONCOMBUST MATL
# 2                    MAINTAIN WINDOW
# 3         POST OWNER/MANAGERS NAME/#
# 4      REPLCE WINDOW PANES, PLEXGLAS
# 5         ARRANGE PREMISE INSPECTION
# 6           OBSTRUCTIONS IN EXIT WAY
# 7                REPAIR WINDOW SILLS
# 8         POST OWNER/MANAGERS NAME/#
# 9         ARRANGE PREMISE INSPECTION
# 10            REPAIR WINDOW HARDWARE
# 11                           CHIMNEY
# 12               REPAIR PORCH SYSTEM
# 13    REPAIR/WRECK DANGER RESID PREM
# 14          CUT OR REMOVE HIGH WEEDS
# ...
# 49985              REPAIR DOOR HARDWARE
# 49986                     PRV HIGH SIDE
# 49987      PERMIT REQUIRED - CONTRACTOR
# 49988            FILE BLDG REGISTRATION
# 49989              REPAIR EXTERIOR DOOR
# 49990        ARRANGE PREMISE INSPECTION
# 49991              REPUTTY WINDOW PANES
# 49992                    REPAIR SCREENS
# 49993    SERVICE WALK, PASSAGE, AREAWAY
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df.describe()
# Out:
#                    id  inspection_number  property_group      latitude  \
# count    50000.000000       50000.000000    50000.000000  49952.000000
# mean   3300031.329640     6195288.986320   197729.741420     41.845539
# std    1088123.083684     4296079.998463   183132.260836      0.087437
# min     742158.000000      375113.000000     1001.000000     41.644712
# 25%    2400057.500000     2021217.500000    20600.750000     41.771440
# 50%    3421152.000000     2813561.000000   142605.000000     41.854001
# 75%    4223617.750000    10630848.750000   363929.250000     41.912843
# max    5064815.000000    11597625.000000   663759.000000     42.022645
#
#           longitude       new_lat
# count  49952.000000  49952.000000
# mean     -87.673442     42.345418
# std        0.057008      0.300692
# min      -87.914436     41.655487
# 25%      -87.714271     42.097803
# 50%      -87.670709     42.344695
# 75%      -87.634551     42.594279
# max      -87.525898     43.016988
#
# ...
